# %% [markdown]
# # Test inspection

# %% [markdown]
# ## 0. Setup

# %% [markdown]
# ### 0.1. Imports

# %%
from pathlib import Path
import subprocess
import sys

# %% [markdown]
# ### 0.2. Project root setup

# %%
def find_project_root(start: Path | None = None) -> Path:
    """
    Find the project root by walking upward from the current directory.

    The project root is identified by the presence of pyproject.toml.
    """
    current = Path.cwd() if start is None else start.resolve()

    for path in [current, *current.parents]:
        if (path / "pyproject.toml").exists():
            return path

    raise FileNotFoundError("Could not find project root containing pyproject.toml.")

# %%
PROJECT_ROOT = find_project_root()

# %% [markdown]
# ## 1. Configs test

# %%
CONFIG_TEST_FOLDER = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Configs"
    
)

# %% [markdown]
# ### 1.1. test_conversion.py

# %% [markdown]
# This test validates the low-level config conversion utilities.
# It checks that
# - YAML, JSON, and TOML configs are correctly loaded as dictionaries,
# - saving then reloading preserves the config content,
# - unsupported extensions or non-dictionary configs fail explicitly with clear errors.

# %%
CONFIG_TEST_CONVERSION_FILE = (
    PROJECT_ROOT
    / CONFIG_TEST_FOLDER
    / "test_conversion.py"
)

# %%
test_conversion_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(CONFIG_TEST_CONVERSION_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_conversion_result.stdout)
print(test_conversion_result.stderr)

assert test_conversion_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 9 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_conversion.py::test_load_yaml_config PASSED [ 11%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_conversion.py::test_load_json_config PASSED [ 22%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_conversion.py::test_load_toml_config PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_conversion.py::test_load_unsupported_extension_raises PASSED [ 44%]
# ...

# %% [markdown]
# ### 1.2. test_merge.py

# %% [markdown]
# This test validates recursive config merging:
# - nested overrides replace matching values, base configs are not mutated,
# - `None` overrides return independent copies,
# - strict mode rejects unknown keys,
# - non-strict mode accepts them,
# - invalid input types fail explicitly.

# %%
CONFIG_TEST_MERGE_FILE = (
    PROJECT_ROOT
    / CONFIG_TEST_FOLDER
    / "test_merge.py"
)

test_merge_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(CONFIG_TEST_MERGE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_merge_result.stdout)
print(test_merge_result.stderr)

assert test_merge_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 7 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_merge.py::test_merge_nested_override PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_merge.py::test_merge_does_not_mutate_base_config PASSED [ 28%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_merge.py::test_merge_none_override_returns_independent_copy PASSED [ 42%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_merge.py::test_merge_strict_unknown_key_raises PASSED [ 57%]
# ...

# %% [markdown]
# ### 1.3. test_overrides.py

# %% [markdown]
# This test validates explicit config override application.
# It checks that:
# - nested override dictionaries are applied correctly,
# - keyword overrides replace top-level entries,
# - dictionary overrides and keyword overrides can be combined,
# - missing overrides return an independent copy,
# - strict and non-strict unknown-key behavior works as expected.

# %%
CONFIG_TEST_OVERRIDES_FILE = (
    PROJECT_ROOT
    / CONFIG_TEST_FOLDER
    / "test_overrides.py"
)

test_overrides_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(CONFIG_TEST_OVERRIDES_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_overrides_result.stdout)
print(test_overrides_result.stderr)

assert test_overrides_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_overrides.py::test_apply_nested_overrides_dict PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_overrides.py::test_apply_kwargs_top_level_override PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_overrides.py::test_apply_overrides_and_kwargs PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_overrides.py::test_apply_no_overrides_returns_independent_copy PASSED [ 66%]
# ...

# %% [markdown]
# ### 1.4. test_savings.py

# %% [markdown]
# This test validates config snapshot saving.
# It checks that:
# - config snapshots are written and reloadable,
# - runtime context snapshots are written and reloadable,
# - combined execution snapshots write both files,
# - snapshot directories work as both `Path` and `str`.

# %%
CONFIG_TEST_SAVINGS_FILE = (
    PROJECT_ROOT
    / CONFIG_TEST_FOLDER
    / "test_savings.py"
)

test_savings_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(CONFIG_TEST_SAVINGS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_savings_result.stdout)
print(test_savings_result.stderr)

assert test_savings_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 4 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_savings.py::test_save_config_snapshot PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_savings.py::test_save_runtime_context_snapshot PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_savings.py::test_save_execution_snapshots PASSED [ 75%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_savings.py::test_save_execution_snapshots_with_string_snapshot_dir PASSED [100%]
#
# ...

# %% [markdown]
# ### 1.5. test_project_defaults.py

# %% [markdown]
# This test validates project-wide default config conventions.
# It checks that:
# - every discovered `DEFAULT_*_CONFIG*` object in `src/**/configs.py` is a dictionary,
# - every default config can be saved to YAML and reloaded,
# - YAML round-trip equality holds, catching non-plain config values such as tuples.

# %%
CONFIG_TEST_PROJECT_DEFAULTS_FILE = (
    PROJECT_ROOT
    / CONFIG_TEST_FOLDER
    / "test_project_defaults.py"
)

test_project_defaults_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(CONFIG_TEST_PROJECT_DEFAULTS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_project_defaults_result.stdout)
print(test_project_defaults_result.stderr)

assert test_project_defaults_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 2 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_project_defaults.py::test_project_default_configs_are_dicts PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_project_defaults.py::test_project_default_configs_are_yaml_round_trip_safe PASSED [100%]
#
# ============================== 2 passed in 2.86s ==============================

# %% [markdown]
# ### 1.6. test_resolve.py

# %% [markdown]
# This test validates the recursive config resolution framework used for modular experiment configs.
#
# - Validates recursive config resolution behavior for elementary config folders.
# - Verifies that same-folder YAML references are correctly expanded into one resolved config.
# - Tests nested and recursive config references.
# - Ensures non-reference strings are preserved unchanged.
# - Checks that the resolved sibling YAML file is correctly written.
# - Validates failure behavior for:
#   - missing config paths,
#   - missing `execution.yaml`,
#   - missing referenced files,
#   - cyclic references,
#   - unsupported config extensions.

# %%
CONFIG_TEST_RESOLVE_FILE = (
    PROJECT_ROOT
    / CONFIG_TEST_FOLDER
    / "test_resolve.py"
)

test_resolve_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(CONFIG_TEST_RESOLVE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_resolve_result.stdout)
print(test_resolve_result.stderr)

assert test_resolve_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 14 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_resolve.py::test_resolve_file_returns_same_path PASSED [  7%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_resolve.py::test_resolve_folder_writes_sibling_yaml PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_resolve.py::test_resolve_folder_resolves_top_level_references PASSED [ 21%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Configs/test_resolve.py::test_resolve_folder_resolves_nested_references PASSED [ 28%]
# ...

# %% [markdown]
# ## 2. Factory

# %%
FACTORY_TEST_FOLDER = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Factory"
    
)

# %% [markdown]
# ### 2.1. test_base_builer.py

# %% [markdown]
# This test validates the generic `BaseBuilder` factory behavior.
# It checks that:
# - default configs are copied and validated,
# - user configs are not mutated during building,
# - runtime context and extra arguments are propagated correctly,
# - strict and non-strict validation behavior works as expected,
# - invalid config structures fail explicitly.

# %%
FACTORY_TEST_BASE_BUILDER_FILE = (
    PROJECT_ROOT
    / FACTORY_TEST_FOLDER
    / "test_base_builder.py"
)

test_base_builder_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(FACTORY_TEST_BASE_BUILDER_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_builder_result.stdout)
print(test_base_builder_result.stderr)

assert test_base_builder_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 10 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Factory/test_base_builder.py::test_builder_copies_default_config PASSED [ 10%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Factory/test_base_builder.py::test_builder_rejects_non_dict_default_config PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Factory/test_base_builder.py::test_builder_call_returns_build_result PASSED [ 30%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Factory/test_base_builder.py::test_builder_call_does_not_mutate_user_config PASSED [ 40%]
# ...

# %% [markdown]
# ### 2.2. test_base_builder_dispatcher.py

# %% [markdown]
# This test validates the generic `BaseBuilderDispatcher` factory behavior.
# It checks that:
# - builder registries are validated correctly,
# - unknown or invalid object configs fail explicitly,
# - registered objects are dispatched to the correct builders,
# - dispatcher outputs preserve object names,
# - runtime context and extra arguments are propagated to child builders,
# - strict and non-strict validation modes behave as expected.

# %%
FACTORY_TEST_BASE_BUILDER_DISPATCHER_FILE = (
    PROJECT_ROOT
    / FACTORY_TEST_FOLDER
    / "test_base_builder_dispatcher.py"
)

test_base_builder_dispatcher_result = subprocess.run(
    [
        sys.executable,
        "-m",
        "pytest",
        str(FACTORY_TEST_BASE_BUILDER_DISPATCHER_FILE),
        "-v",
    ],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_builder_dispatcher_result.stdout)
print(test_base_builder_dispatcher_result.stderr)

assert test_base_builder_dispatcher_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 10 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Factory/test_base_builder_dispatcher.py::test_dispatcher_rejects_non_dict_registry PASSED [ 10%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Factory/test_base_builder_dispatcher.py::test_dispatcher_rejects_non_string_registry_key PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Factory/test_base_builder_dispatcher.py::test_dispatcher_rejects_non_callable_registry_value PASSED [ 30%]
# ...

# %% [markdown]
# ## 3. Models

# %%
MODELS_TEST_FOLDER = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Models"
    
)

# %% [markdown]
# ### 3.1. test_factory.py

# %% [markdown]
# This test validates generic model factory behavior.
# It checks that:
# - default model configs build successfully,
# - `build_models` returns a model dictionary,
# - the default `waveunet` entry builds a `WaveUNet`,
# - unknown model names fail explicitly in strict mode,
# - non-strict mode returns `None` for invalid model configs.

# %%
MODELS_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / MODELS_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(MODELS_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 4 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_factory.py::test_build_models_returns_model_dict PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_factory.py::test_build_models_builds_default_waveunet PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_factory.py::test_build_models_rejects_unknown_model_name PASSED [ 75%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_factory.py::test_build_models_non_strict_unknown_model_returns_none PASSED [100%]
#
# ...

# %% [markdown]
# ### 3.2. test_waveunet.py

# %% [markdown]
# This test validates WaveUNet-specific model behavior.
# It checks that:
# - `WaveUNetBuilder` builds a `WaveUNet`,
# - the forward pass runs on dummy waveform batches,
# - output shape matches input shape,
# - outputs are bounded by the final `tanh` activation.

# %%
MODELS_TEST_WAVEUNET_FILE = (
    PROJECT_ROOT
    / MODELS_TEST_FOLDER
    / "test_waveunet.py"
)

test_waveunet_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(MODELS_TEST_WAVEUNET_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_waveunet_result.stdout)
print(test_waveunet_result.stderr)

assert test_waveunet_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 4 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_waveunet.py::test_waveunet_builder_builds_waveunet PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_waveunet.py::test_waveunet_forward_runs PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_waveunet.py::test_waveunet_output_shape_matches_input_shape PASSED [ 75%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Models/test_waveunet.py::test_waveunet_output_is_tanh_bounded PASSED [100%]
#
# ...

# %% [markdown]
# ## 4. Metrics

# %%
METRICS_TEST_FOLDER = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Metrics"
    
)

# %% [markdown]
# ### 4.1. test_loss.py

# %% [markdown]
# This test validates weighted metric loss behavior.
# It checks that:
# - inactive weights are filtered out,
# - positive and negative weights follow the minimization/maximization convention,
# - loss logs contain the expected entries,
# - strict and non-strict missing-metric behavior works,
# - invalid metric names, weights, and values fail explicitly.

# %%
METRICS_TEST_LOSS_FILE = (
    PROJECT_ROOT
    / METRICS_TEST_FOLDER
    / "test_loss.py"
)

test_loss_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(METRICS_TEST_LOSS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_loss_result.stdout)
print(test_loss_result.stderr)

assert test_loss_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 11 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_loss.py::test_loss_filters_inactive_weights PASSED [  9%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_loss.py::test_loss_positive_and_negative_weights PASSED [ 18%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_loss.py::test_loss_returns_loss_terms_by_default PASSED [ 27%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_loss.py::test_loss_can_return_only_total_loss_log PASSED [ 36%]
# ...

# %% [markdown]
# ### 4.2. test_base.py

# %% [markdown]
# This test validates shared metric base behavior.
# It checks that:
# - reduction modes behave correctly,
# - shape and single-channel validations work,
# - autograd-tracked tensors are rejected when required,
# - tensor shape helpers preserve the expected conventions.

# %%
METRICS_TEST_BASE_FILE = (
    PROJECT_ROOT
    / METRICS_TEST_FOLDER
    / "test_base.py"
)

test_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(METRICS_TEST_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_result.stdout)
print(test_base_result.stderr)

assert test_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 16 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_base.py::test_base_metric_mean_reduction PASSED [  6%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_base.py::test_base_metric_sum_reduction PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_base.py::test_base_metric_none_reduction PASSED [ 18%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_base.py::test_base_metric_invalid_reduction_raises PASSED [ 25%]
# ...

# %% [markdown]
# ### 4.3. test_metric_set.py

# %% [markdown]
# This test validates metric set orchestration.
# It checks that:
# - metrics must be valid `nn.Module` objects,
# - tensor, tuple/list, and dictionary inputs are dispatched correctly,
# - strict and non-strict missing-metric behavior works,
# - metric outputs are flattened into log-ready dictionaries,
# - `TSEMetricSet` correctly routes TSE inputs to registered metrics.

# %%
METRICS_TEST_METRIC_SET_FILE = (
    PROJECT_ROOT
    / METRICS_TEST_FOLDER
    / "test_metric_set.py"
)

test_metric_set_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(METRICS_TEST_METRIC_SET_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_metric_set_result.stdout)
print(test_metric_set_result.stderr)

assert test_metric_set_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 14 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_metric_set.py::test_metric_set_rejects_non_module_metric PASSED [  7%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_metric_set.py::test_metric_set_strict_missing_metric_raises PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_metric_set.py::test_metric_set_non_strict_missing_metric_is_skipped PASSED [ 21%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_metric_set.py::test_metric_set_calls_metric_with_tensor_input PASSED [ 28%]
# ...

# %% [markdown]
# ### 4.4. test_factory.py

# %% [markdown]
# This test validates metric factory behavior.
# It checks that:
# - individual metrics can be built,
# - metric dispatchers build registered lightweight metrics,
# - unknown metrics fail according to strictness,
# - light TSE metric sets are buildable,
# - weighted metric losses are buildable and reject unknown loss types.

# %%
METRICS_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / METRICS_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(METRICS_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_factory.py::test_metric_builder_builds_metric PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_factory.py::test_metric_dispatcher_builds_metrics PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_factory.py::test_metric_dispatcher_rejects_unknown_metric PASSED [ 37%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_factory.py::test_metric_dispatcher_non_strict_unknown_metric_returns_none PASSED [ 50%]
# ...

# %% [markdown]
# ### 4.5. test_objective.py

# %% [markdown]
# This test validates objective metric behavior.
# It checks that:
# - waveform, scale-invariant, spectral, and DTW metrics run correctly,
# - metrics return tensors with the expected reduction behavior,
# - DTW correctly enforces evaluation-only usage,
# - intrusive metrics reject invalid shapes and multi-channel inputs.

# %%
METRICS_TEST_OBJECTIVE_FILE = (
    PROJECT_ROOT
    / METRICS_TEST_FOLDER
    / "test_objective.py"
)

test_objective_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(METRICS_TEST_OBJECTIVE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_objective_result.stdout)
print(test_objective_result.stderr)

assert test_objective_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 15 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_objective.py::test_snr_forward_returns_scalar PASSED [  6%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_objective.py::test_sisdr_forward_returns_scalar PASSED [ 13%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_objective.py::test_sdsdr_forward_returns_scalar PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_objective.py::test_lpnorm_forward_returns_scalar PASSED [ 26%]
# ...

# %% [markdown]
# ### 4.6. test_subjective.py

# %% [markdown]
# This test validates subjective metric behavior.
# It checks that:
# - STOI, ESTOI, PESQ, and DNSMOS variants run correctly,
# - subjective metrics enforce evaluation-only usage,
# - reduction behavior is consistent,
# - invalid PESQ configs fail explicitly,
# - invalid shapes and multi-channel inputs are rejected.

# %%
METRICS_TEST_SUBJECTIVE_FILE = (
    PROJECT_ROOT
    / METRICS_TEST_FOLDER
    / "test_subjective.py"
)

test_subjective_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(METRICS_TEST_SUBJECTIVE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_subjective_result.stdout)
print(test_subjective_result.stderr)

assert test_subjective_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 18 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_subjective.py::test_stoi_forward_returns_scalar PASSED [  5%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_subjective.py::test_estoi_forward_returns_scalar PASSED [ 11%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_subjective.py::test_stoi_rejects_autograd_tracked_inputs PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Metrics/test_subjective.py::test_estoi_rejects_autograd_tracked_inputs PASSED [ 22%]
# ...

# %% [markdown]
# ## 5. Optimization

# %%
OPTIMIZATION_TEST_FOLDER = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Optimization"
    
)

# %% [markdown]
# ### 5.1. test_factory.py

# %% [markdown]
# This test validates optimizer and scheduler factory behavior.
# It checks that:
# - optimizers and schedulers build successfully from default configs,
# - optimizer and scheduler routing works correctly,
# - model parameter extraction works,
# - all registered optimizer and scheduler types are buildable,
# - unknown types and missing parameter/optimizer groups fail explicitly.

# %%
OPTIMIZATION_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / OPTIMIZATION_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(OPTIMIZATION_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 15 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Optimization/test_factory.py::test_build_optimizers_builds_default_optimizer PASSED [  6%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Optimization/test_factory.py::test_build_optimizers_from_models_extracts_parameters PASSED [ 13%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Optimization/test_factory.py::test_build_optimizers_builds_sgd PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Optimization/test_factory.py::test_build_optimizers_builds_adam PASSED [ 26%]
# ...

# %% [markdown]
# ## 6. Data Processing

# %%
DATA_PROCESSING_TEST_FOLDER = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "DataProcessing"
    
)

# %% [markdown]
# ### 6.1. test_base.py

# %% [markdown]
# This test validates shared data-processing base behavior.
# It checks that:
# - batch transforms enforce dictionary inputs and outputs,
# - required keys and tensor shapes are validated,
# - collators reject invalid sample lists,
# - collated batches must be dictionaries,
# - transforms are applied in order.

# %%
DATA_PROCESSING_TEST_BASE_FILE = (
    PROJECT_ROOT
    / DATA_PROCESSING_TEST_FOLDER
    / "test_base.py"
)

test_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATA_PROCESSING_TEST_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_result.stdout)
print(test_base_result.stderr)

assert test_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 10 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_base.py::test_base_batch_transform_rejects_non_dict_input PASSED [ 10%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_base.py::test_base_batch_transform_rejects_non_dict_output PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_base.py::test_base_batch_transform_checks_required_key PASSED [ 30%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_base.py::test_base_batch_transform_checks_tensor PASSED [ 40%]
# ...

# %% [markdown]
# ### 6.2. test_transforms.py

# %% [markdown]
# This test validates batch transform behavior.
# It checks that:
# - `AddNoiseAtSNR` updates the expected output key,
# - tensor shapes and unrelated batch entries are preserved,
# - invalid inputs fail explicitly,
# - power computation is broadcastable,
# - the empirical SNR matches the requested value.

# %%
DATA_PROCESSING_TEST_TRANSFORMS_FILE = (
    PROJECT_ROOT
    / DATA_PROCESSING_TEST_FOLDER
    / "test_transforms.py"
)

test_transforms_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATA_PROCESSING_TEST_TRANSFORMS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_transforms_result.stdout)
print(test_transforms_result.stderr)

assert test_transforms_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_transforms.py::test_add_noise_at_snr_updates_output_key PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_transforms.py::test_add_noise_at_snr_preserves_output_shape PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_transforms.py::test_add_noise_at_snr_preserves_other_keys PASSED [ 37%]
# ...

# %% [markdown]
# ### 6.3. test_collators.py

# %% [markdown]
# This test validates TSE waveform collator behavior.
# It checks that:
# - mixtures and targets are stacked correctly,
# - metadata and clues are collated as expected,
# - transforms are applied after collation,
# - missing required sample keys fail explicitly.

# %%
DATA_PROCESSING_TEST_COLLATORS_FILE = (
    PROJECT_ROOT
    / DATA_PROCESSING_TEST_FOLDER
    / "test_collators.py"
)

test_collators_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATA_PROCESSING_TEST_COLLATORS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_collators_result.stdout)
print(test_collators_result.stderr)

assert test_collators_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_collators.py::test_tse_waveform_collator_stacks_mixture_and_target PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_collators.py::test_tse_waveform_collator_returns_metadata_list PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_collators.py::test_tse_waveform_collator_returns_none_when_all_clues_are_none PASSED [ 37%]
# ...

# %% [markdown]
# ### 6.4. test_factory.py

# %% [markdown]
# This test validates data-processing factory behavior.
# It checks that:
# - transform configs build ordered transform lists,
# - invalid transform names fail explicitly,
# - named collator configs follow the global factory convention,
# - default and noisy TSE collators build correctly,
# - transform order is preserved inside collators.

# %%
DATA_PROCESSING_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / DATA_PROCESSING_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATA_PROCESSING_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 9 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_factory.py::test_build_transforms_none_returns_empty_list PASSED [ 11%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_factory.py::test_build_transforms_empty_config_returns_empty_list PASSED [ 22%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataProcessing/test_factory.py::test_build_transforms_builds_add_noise_at_snr PASSED [ 33%]
# ...

# %% [markdown]
# ## 7. Datasets

# %%
DATASETS_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Datasets"
    
)

# %% [markdown]
# ### 7.1. test_base.py

# %% [markdown]
# This test validates the generic dataset base class.
#
# It checks that:
# - raw data is converted to tensors using the dataset canonical dtype;
# - generic samples follow the `input` / `target` / `metadata` convention;
# - missing required sample keys are rejected;
# - non-dictionary samples are rejected;
# - non-dictionary metadata is rejected.

# %%
DATASETS_TEST_BASE_FILE = (
    PROJECT_ROOT
    / DATASETS_TEST_FOLDER
    / "test_base.py"
)

test_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATASETS_TEST_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_result.stdout)
print(test_base_result.stderr)

assert test_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 7 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_base.py::test_base_dataset_to_tensor_uses_canonical_dtype PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_base.py::test_base_dataset_build_sample_with_metadata PASSED [ 28%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_base.py::test_base_dataset_build_sample_defaults_to_empty_metadata PASSED [ 42%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_base.py::test_base_dataset_check_required_keys_accepts_valid_sample PASSED [ 57%]
# ...

# %% [markdown]
# ### 7.2. test_waveform_base.py

# %% [markdown]
# This test validates the waveform dataset base class.
#
# It checks that:
# - raw audio is converted to single-channel waveform tensors;
# - existing channel dimensions are preserved;
# - canonical dtype is respected;
# - waveform normalization uses the reference peak amplitude;
# - grouped waveform normalization rejects missing reference keys.

# %%
DATASETS_TEST_WAVEFORM_BASE_FILE = (
    PROJECT_ROOT
    / DATASETS_TEST_FOLDER
    / "test_waveform_base.py"
)

test_waveform_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATASETS_TEST_WAVEFORM_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_waveform_base_result.stdout)
print(test_waveform_base_result.stderr)

assert test_waveform_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_waveform_base.py::test_waveform_base_to_waveform_tensor_converts_1d_audio_to_single_channel PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_waveform_base.py::test_waveform_base_to_waveform_tensor_preserves_existing_channel_dimension PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_waveform_base.py::test_waveform_base_to_waveform_tensor_uses_canonical_dtype PASSED [ 50%]
# ...

# %% [markdown]
# ### 7.3. test_tse_base.py

# %% [markdown]
# This test validates the TSE dataset base classes.
#
# It checks that:
# - TSE samples follow the `mixture` / `target` / `clue` / `metadata` convention;
# - clued TSE samples reject `clue=None`;
# - paired TSE datasets preserve base dataset length;
# - base samples and clue samples are correctly paired through metadata;
# - missing clue lookup keys are rejected;
# - clue metadata is nested under `clue_metadata`.

# %%
DATASETS_TEST_TSE_BASE_FILE = (
    PROJECT_ROOT
    / DATASETS_TEST_FOLDER
    / "test_tse_base.py"
)

test_tse_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATASETS_TEST_TSE_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_tse_base_result.stdout)
print(test_tse_base_result.stderr)

assert test_tse_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_tse_base.py::test_base_tse_dataset_build_tse_sample PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_tse_base.py::test_base_tse_dataset_check_sample_accepts_valid_tse_sample PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_tse_base.py::test_base_tse_dataset_check_sample_rejects_missing_required_key PASSED [ 37%]
# ...

# %% [markdown]
# ### 7.4. test_base_clue_dataset.py

# %% [markdown]
# This test validates the clue dataset base class.
#
# It checks that:
# - clue samples follow the `clue` / `metadata` convention;
# - missing metadata defaults to an empty dictionary;
# - non-dictionary clue samples are rejected;
# - missing required clue sample keys are rejected;
# - non-dictionary metadata is rejected;
# - clue lookup keys cannot be `None`.

# %%
DATASETS_TEST_CLUE_BASE_FILE = (
    PROJECT_ROOT
    / DATASETS_TEST_FOLDER
    / "test_base_clue_dataset.py"
)

test_base_clue_dataset_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATASETS_TEST_CLUE_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_clue_dataset_result.stdout)
print(test_base_clue_dataset_result.stderr)

assert test_base_clue_dataset_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_base_clue_dataset.py::test_clue_base_dataset_build_clue_sample_with_metadata PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_base_clue_dataset.py::test_clue_base_dataset_build_clue_sample_defaults_to_empty_metadata PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_base_clue_dataset.py::test_clue_base_dataset_check_sample_accepts_valid_clue_sample PASSED [ 37%]
# ...

# %% [markdown]
# ### 7.5. test_toy_dataset.py

# %% [markdown]
# This test validates the toy source-separation dataset.
#
# It checks that:
# - invalid dataset folders are rejected;
# - synthetic wav samples are loaded correctly;
# - dataset length matches the number of sample folders;
# - returned samples follow the TSE convention;
# - waveforms are single-channel tensors;
# - SNR metadata is extracted from mix filenames;
# - on-demand loading is supported;
# - mixture-peak normalization keeps mixture amplitude bounded.

# %%
DATASETS_TEST_TOY_DATASET_FILE = (
    PROJECT_ROOT
    / DATASETS_TEST_FOLDER
    / "test_toy_dataset.py"
)

test_toy_dataset_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATASETS_TEST_TOY_DATASET_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_toy_dataset_result.stdout)
print(test_toy_dataset_result.stderr)

assert test_toy_dataset_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 9 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_toy_dataset.py::test_source_separation_dataset_rejects_invalid_folder PASSED [ 11%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_toy_dataset.py::test_source_separation_dataset_initializes_from_toy_folder PASSED [ 22%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_toy_dataset.py::test_source_separation_dataset_extract_snr_from_mix_filename PASSED [ 33%]
# ...

# %% [markdown]
# ### 7.6. test_factory.py

# %% [markdown]
# This test validates the dataset factory.
#
# It checks that:
# - serializable dtype names are resolved to torch dtypes;
# - dataset paths are resolved from direct paths or runtime context keys;
# - invalid path specifications are rejected;
# - source-separation datasets are built from config;
# - unknown dataset names are rejected;
# - input configs are not mutated during construction.

# %%
DATASETS_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / DATASETS_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATASETS_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 9 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_factory.py::test_dataset_builder_resolve_dtype_accepts_known_dtype PASSED [ 11%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_factory.py::test_dataset_builder_resolve_dtype_rejects_unknown_dtype PASSED [ 22%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Datasets/test_factory.py::test_dataset_builder_resolves_direct_path PASSED [ 33%]
# ...

# %% [markdown]
# ## 8. DataModules

# %%
DATAMODULES_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "DataModules"
    
)

# %% [markdown]
# ### 8.1. test_base.py

# %% [markdown]
# This test validates the generic Lightning DataModule base class.
#
# It checks that:
# - datasets, collators, and DataLoader configs remain phase-consistent;
# - unknown phases are rejected;
# - phases with `None` datasets return no DataLoader;
# - train/validation/test DataLoaders are correctly built;
# - phase-specific collators are used during batching;
# - phase-specific DataLoader configurations are respected.

# %%
DATAMODULES_TEST_BASE_FILE = (
    PROJECT_ROOT
    / DATAMODULES_TEST_FOLDER
    / "test_base.py"
)

test_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATAMODULES_TEST_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_result.stdout)
print(test_base_result.stderr)

assert test_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 10 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataModules/test_base.py::test_base_datamodule_rejects_missing_collator_for_existing_dataset PASSED [ 10%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataModules/test_base.py::test_base_datamodule_rejects_none_collator_for_existing_dataset PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataModules/test_base.py::test_base_datamodule_rejects_missing_dataloader_config_for_existing_dataset PASSED [ 30%]
# ...

# %% [markdown]
# ### 8.2. test_datamodules.py

# %% [markdown]
# This file intentionally contains no executable test.
#
# `DefaultDataModule` currently adds no behavior over `BaseDataModule`; it only exists as the standard concrete DataModule exposed to the factory.
#
# Its behavior is therefore already covered by `tests/DataModules/test_base.py`.

# %%
# DATAMODULES_TEST_DATAMODULES_FILE = (
#     PROJECT_ROOT
#     / DATAMODULES_TEST_FOLDER
#     / "test_datamodules.py"
# )
# 
# test_datamodules_result = subprocess.run(
#     [sys.executable, "-m", "pytest", str(DATAMODULES_TEST_DATAMODULES_FILE), "-v"],
#     cwd=PROJECT_ROOT,
#     text=True,
#     capture_output=True,
# )
# 
# print(test_datamodules_result.stdout)
# print(test_datamodules_result.stderr)
# 
# assert test_datamodules_result.returncode == 0


print(
    "tests/DataModules/test_datamodules.py intentionally contains no executable test. "
    "DefaultDataModule currently adds no behavior over BaseDataModule, so behavior is "
    "covered by tests/DataModules/test_base.py."
)
# Out:
# tests/DataModules/test_datamodules.py intentionally contains no executable test. DefaultDataModule currently adds no behavior over BaseDataModule, so behavior is covered by tests/DataModules/test_base.py.

# %% [markdown]
# ### 8.3. test_factory.py

# %% [markdown]
# This test validates the DataModule factory.
#
# It checks that:
# - DataModule configs follow the global named factory convention;
# - datasets are built phase by phase;
# - collators are built phase by phase;
# - single named DataModules can be unwrapped;
# - invalid DataModule names are rejected;
# - runtime context is forwarded to dataset construction;
# - input configs are not mutated during construction.

# %%
DATAMODULES_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / DATAMODULES_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(DATAMODULES_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 10 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataModules/test_factory.py::test_datamodule_builder_build_phase_datasets_builds_phase_datasets PASSED [ 10%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataModules/test_factory.py::test_datamodule_builder_build_phase_datasets_preserves_none_dataset PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/DataModules/test_factory.py::test_datamodule_builder_build_phase_collators_builds_phase_collators PASSED [ 30%]
# ...

# %% [markdown]
# ## 9. Modules

# %%
MODULES_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Modules"
    
)

# %% [markdown]
# ### 9.1. test_base.py

# %% [markdown]
# This test validates the generic Lightning module base class.
#
# It checks that:
# - models are registered as a `ModuleDict`;
# - valid ML steps are accepted;
# - invalid ML steps are rejected;
# - log dictionaries are validated;
# - duplicate log keys are rejected before prefixing;
# - log dictionaries are correctly merged and prefixed;
# - optimizer construction works from grouped model/config dictionaries;
# - optimizer-only configurations return optimizer lists without schedulers.

# %%
MODULES_TEST_BASE_FILE = (
    PROJECT_ROOT
    / MODULES_TEST_FOLDER
    / "test_base.py"
)

test_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(MODULES_TEST_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_base_result.stdout)
print(test_base_result.stderr)

assert test_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 12 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_base.py::test_base_lightning_module_stores_models_as_module_dict PASSED [  8%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_base.py::test_base_lightning_module_check_ml_step_accepts_valid_steps PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_base.py::test_base_lightning_module_check_ml_step_rejects_invalid_step PASSED [ 25%]
# ...

# %% [markdown]
# ### 9.2. test_tse_base.py

# %% [markdown]
# This test validates the TSE Lightning module base class.
#
# It checks that:
# - the correct metric set is selected from the ML step;
# - invalid ML steps are rejected;
# - metric computation is forwarded to the selected metric set;
# - loss computation is forwarded to the metric-based loss object;
# - training-step processing returns the computed loss;
# - validation-step processing can optionally compute and return the loss;
# - test-step processing returns `None` by default when loss logging is disabled for the phase.

# %%
MODULES_TEST_TSE_BASE_FILE = (
    PROJECT_ROOT
    / MODULES_TEST_FOLDER
    / "test_tse_base.py"
)

test_tse_base_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(MODULES_TEST_TSE_BASE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_tse_base_result.stdout)
print(test_tse_base_result.stderr)

assert test_tse_base_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 7 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_tse_base.py::test_tse_base_lightning_module_get_tse_metric_set_returns_phase_metric_set PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_tse_base.py::test_tse_base_lightning_module_get_tse_metric_set_rejects_invalid_step PASSED [ 28%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_tse_base.py::test_tse_base_lightning_module_compute_tse_metrics_calls_selected_metric_set PASSED [ 42%]
# ...

# %% [markdown]
# ### 9.3. test_waveunet.py

# %% [markdown]
# This test validates the WaveUNet Lightning module wrapper.
#
# It checks that:
# - the module correctly inherits from `TSEBaseLightningModule`;
# - the wrapped WaveUNet model is correctly stored;
# - the forward pass delegates to the wrapped model;
# - training-step processing computes and returns the loss;
# - validation-step processing runs correctly;
# - test-step processing runs correctly.
#
# This test intentionally uses dummy metric/loss objects and monkeypatched logging to isolate project-owned wrapper logic from Lightning internals and metric implementations.

# %%
MODULES_TEST_WAVEUNET_FILE = (
    PROJECT_ROOT
    / MODULES_TEST_FOLDER
    / "test_waveunet.py"
)

test_waveunet_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(MODULES_TEST_WAVEUNET_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_waveunet_result.stdout)
print(test_waveunet_result.stderr)

assert test_waveunet_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_waveunet.py::test_waveunet_lightning_module_is_tse_base_lightning_module PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_waveunet.py::test_waveunet_lightning_module_stores_waveunet_model PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_waveunet.py::test_waveunet_lightning_module_forward_runs PASSED [ 50%]
# ...

# %% [markdown]
# ### 9.4. test_factory.py

# %% [markdown]
# This test validates the Lightning module factory.
#
# It checks that:
# - model loading configs are correctly extracted from loading dictionaries;
# - WaveUNet Lightning modules are correctly built from named configs;
# - unknown Lightning module names are rejected;
# - multiple named Lightning module configs are rejected;
# - loading configs are correctly forwarded to model-loading utilities.
#
# This test intentionally monkeypatches factory dependencies such as:
# - model builders;
# - metric builders;
# - loss builders;
# - model-loading utilities.
#
# `pytest.MonkeyPatch` temporarily replaces these functions during the test, allowing the factory orchestration logic to be isolated from heavy model construction, checkpoint loading, metric implementations, and external dependencies.

# %%
MODULES_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / MODULES_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(MODULES_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_factory.py::test_get_model_loading_config_returns_none_without_loading_config PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_factory.py::test_get_model_loading_config_extracts_model_entry PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Modules/test_factory.py::test_build_lightning_module_builds_waveunet_module PASSED [ 50%]
# ...

# %% [markdown]
# ## 10. Setup

# %%
SETUP_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Setup"
    
)

# %% [markdown]
# ### 10.1. test_project_root.py

# %% [markdown]
# This test validates project-root-aware path resolution utilities.It checks that:
# - the project root is correctly inferred from elementary config folders;
# - the project root is correctly inferred from resolved config files;
# - explicit project roots are correctly resolved and validated;
# - relative paths are resolved from the project root;
# - absolute paths are preserved during resolution;
# - user credential paths are resolved relative to the project root independently of the current working directory.

# %%
SETUP_TEST_PROJECT_ROOT_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_project_root.py"
)

test_project_root_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_PROJECT_ROOT_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_project_root_result.stdout)
print(test_project_root_result.stderr)

assert test_project_root_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_project_root.py::test_infer_project_root_from_elementary_config_folder PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_project_root.py::test_infer_project_root_from_resolved_config_file PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_project_root.py::test_resolve_project_root_uses_explicit_root_when_provided PASSED [ 50%]
# ...

# %% [markdown]
# ### 10.1. test_environment.py

# %% [markdown]
# This test validates environment setup utilities.
#
# It checks that:
# - existing Python modules are accepted;
# - missing Python modules are rejected;
# - multiple required imports are checked;
# - default environment setup returns an empty import tuple;
# - configured required imports are returned as a tuple.

# %%
SETUP_TEST_ENVIRONMENT_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_environment.py"
)

test_environment_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_ENVIRONMENT_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_environment_result.stdout)
print(test_environment_result.stderr)

assert test_environment_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_environment.py::test_check_required_import_accepts_existing_module PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_environment.py::test_check_required_import_rejects_missing_module PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_environment.py::test_check_required_imports_accepts_existing_modules PASSED [ 50%]
# ...

# %% [markdown]
# ### 10.2 test_hardware.py

# %% [markdown]
# This test validates hardware setup utilities.
#
# It checks that:
# - hardware diagnostics return the expected context keys;
# - CUDA device-name lookup handles zero devices;
# - CUDA requirements are rejected when unavailable;
# - device-count requests are validated;
# - accelerator requests are validated;
# - hardware setup returns requested and available runtime contexts.

# %%
SETUP_TEST_HARDWARE_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_hardware.py"
)

test_hardware_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_HARDWARE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_hardware_result.stdout)
print(test_hardware_result.stderr)

assert test_hardware_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 10 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_hardware.py::test_get_hardware_info_returns_expected_keys PASSED [ 10%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_hardware.py::test_get_cuda_device_names_returns_empty_list_for_zero_devices PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_hardware.py::test_check_cuda_request_accepts_when_cuda_not_required PASSED [ 30%]
# ...

# %% [markdown]
# ### 10.3. test_reproducibility.py

# %% [markdown]
# This test validates reproducibility setup utilities.
#
# It checks that:
# - seed values are validated;
# - deterministic mode requires a boolean value;
# - cuDNN benchmark mode requires a boolean value;
# - reproducibility setup returns the expected context;
# - cuDNN benchmark mode is applied and reset after testing.

# %%
SETUP_TEST_REPRODUCIBILITY_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_reproducibility.py"
)

test_reproducibility_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_REPRODUCIBILITY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_reproducibility_result.stdout)
print(test_reproducibility_result.stderr)

assert test_reproducibility_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 7 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_reproducibility.py::test_check_seed_accepts_non_negative_integer PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_reproducibility.py::test_check_seed_rejects_non_integer_seed PASSED [ 28%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_reproducibility.py::test_check_seed_rejects_negative_seed PASSED [ 42%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_reproducibility.py::test_set_deterministic_mode_rejects_non_bool PASSED [ 57%]
# ...

# %% [markdown]
# ### 10.4. test_paths.py

# %% [markdown]
# This test validates runtime path setup utilities.
#
# It checks that:
# - paths are resolved correctly;
# - single-run and sweep-run directories are constructed correctly;
# - run directories and standard subdirectories are created;
# - existing run directories are handled according to `overwrite`;
# - writable directories are accepted;
# - runtime path contexts are converted to serializable strings.

# %%
SETUP_TEST_PATHS_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_paths.py"
)

test_paths_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_PATHS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_paths_result.stdout)
print(test_paths_result.stderr)

assert test_paths_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 14 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_paths.py::test_resolve_path_returns_absolute_path PASSED [  7%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_paths.py::test_resolve_optional_path_uses_default_when_none PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_paths.py::test_build_sweep_dir_returns_none_without_sweep_name PASSED [ 21%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_paths.py::test_build_sweep_dir_builds_sweep_path PASSED [ 28%]
# ...

# %% [markdown]
# ### 10.5. test_data.py

# %% [markdown]
# This test validates data setup utilities.
#
# It checks that:
# - dataset root paths are resolved;
# - existing dataset directories are accepted;
# - missing dataset directories are rejected;
# - non-directory dataset roots are rejected;
# - multiple dataset roots are checked;
# - returned dataset contexts are serializable.

# %%
SETUP_TEST_DATA_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_data.py"
)

test_data_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_DATA_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_data_result.stdout)
print(test_data_result.stderr)

assert test_data_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_data.py::test_resolve_dataset_roots_resolves_all_paths PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_data.py::test_check_dataset_root_exists_accepts_existing_directory PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_data.py::test_check_dataset_root_exists_rejects_missing_directory PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_data.py::test_check_dataset_root_exists_rejects_non_directory PASSED [ 66%]
# ...

# %% [markdown]
# ### 10.6. test_user_credential.py

# %% [markdown]
# This test validates user credential setup utilities.
#
# It checks that:
# - disabled credential setup returns a safe empty context;
# - missing credential paths are rejected in strict mode;
# - nested credential values are resolved;
# - missing credential keys are rejected;
# - selected credentials are exported as environment variables;
# - secret values are never stored in the runtime context.

# %%
SETUP_TEST_USER_CREDENTIAL_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_user_credential.py"
)

test_user_credential_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_USER_CREDENTIAL_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_user_credential_result.stdout)
print(test_user_credential_result.stderr)

assert test_user_credential_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_user_credential.py::test_setup_user_credential_returns_disabled_context_by_default PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_user_credential.py::test_resolve_credential_path_rejects_missing_path_when_strict PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_user_credential.py::test_get_nested_credential_value_returns_nested_value PASSED [ 50%]
# ...

# %% [markdown]
# ### 10.7. test_logger_registration.py

# %% [markdown]
# This test validates logger registration setup utilities.
#
# It checks that:
# - WandB contexts never store API key values;
# - disabled WandB registration returns a safe context;
# - missing API key environment variables are rejected;
# - WandB login uses the configured environment variable;
# - logger registration dispatches configured logger backends;
# - unknown logger backends are rejected.

# %%
SETUP_TEST_LOGGER_REGISTRATION_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_logger_registration.py"
)

test_logger_registration_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_LOGGER_REGISTRATION_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_logger_registration_result.stdout)
print(test_logger_registration_result.stderr)

assert test_logger_registration_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 7 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_logger_registration.py::test_build_wandb_context_does_not_store_api_key PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_logger_registration.py::test_setup_wandb_registration_returns_disabled_context PASSED [ 28%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_logger_registration.py::test_login_wandb_rejects_missing_api_key_env_var PASSED [ 42%]
# ...

# %% [markdown]
# ### 10.8. test_setup.py

# %% [markdown]
# This test validates the high-level runtime setup orchestrator.
#
# It checks that:
# - all setup sections are included in the runtime context;
# - user credentials are loaded before logger registration;
# - secrets are not stored in the runtime context;
# - path and data contexts are serializable;
# - minimal setup configs can rely on safe defaults.

# %%
SETUP_TEST_SETUP_FILE = (
    PROJECT_ROOT
    / SETUP_TEST_FOLDER
    / "test_setup.py"
)

test_setup_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SETUP_TEST_SETUP_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_setup_result.stdout)
print(test_setup_result.stderr)

assert test_setup_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 4 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_setup.py::test_setup_runtime_returns_all_context_sections PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_setup.py::test_setup_runtime_calls_user_credential_before_logger_registration PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_setup.py::test_setup_runtime_returns_serializable_runtime_context PASSED [ 75%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Setup/test_setup.py::test_setup_runtime_uses_empty_defaults PASSED [100%]
#
# ...

# %% [markdown]
# ## 11. Execution

# %%
EXECUTION_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Execution"
    
)

# %% [markdown]
# ### 11.1. test_cleanup.py

# %% [markdown]
# This test validates execution cleanup utilities.
#
# It checks that:
# - missing WandB imports are safely ignored;
# - inactive WandB runs are safely ignored;
# - active WandB runs are closed;
# - public cleanup dispatches WandB cleanup defensively.

# %%
EXECUTION_TEST_CLEANUP_FILE = (
    PROJECT_ROOT
    / EXECUTION_TEST_FOLDER
    / "test_cleanup.py"
)

test_cleanup_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(EXECUTION_TEST_CLEANUP_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_cleanup_result.stdout)
print(test_cleanup_result.stderr)

assert test_cleanup_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 4 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_cleanup.py::test_close_wandb_if_active_does_nothing_when_wandb_not_imported PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_cleanup.py::test_close_wandb_if_active_does_nothing_when_wandb_has_no_active_run PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_cleanup.py::test_close_wandb_if_active_finishes_active_wandb_run PASSED [ 75%]
# ...

# %% [markdown]
# ### 11.2. test_reports.py

# %% [markdown]
# This test validates execution report utilities.
#
# It checks that:
# - runtime run directories are retrieved correctly;
# - reports are initialized with running status;
# - reports can be marked as finished or failed;
# - nested values are made JSON-serializable;
# - execution reports are saved as JSON files.

# %%
EXECUTION_TEST_REPORTS_FILE = (
    PROJECT_ROOT
    / EXECUTION_TEST_FOLDER
    / "test_reports.py"
)

test_reports_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(EXECUTION_TEST_REPORTS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_reports_result.stdout)
print(test_reports_result.stderr)

assert test_reports_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_reports.py::test_get_run_dir_returns_runtime_context_run_dir PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_reports.py::test_make_json_serializable_preserves_primitives PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_reports.py::test_make_json_serializable_converts_path_to_string PASSED [ 37%]
# ...

# %% [markdown]
# ### 11.3. test_factory.py

# %% [markdown]
# This test validates execution factory utilities.
#
# It checks that:
# - training callbacks are gathered correctly;
# - Trainer construction receives logger, callbacks, and config values;
# - training and evaluation trainers are assembled correctly;
# - training and evaluation execution bundles are built correctly.
#
# `monkeypatch` is used to replace subsystem builders and Lightning `Trainer`, so the test isolates `Execution/` orchestration from lower-level factories and Lightning internals.

# %%
EXECUTION_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / EXECUTION_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(EXECUTION_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 6 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_factory.py::test_build_training_callbacks_gathers_checkpoint_and_early_stopping_callbacks PASSED [ 16%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_factory.py::test_build_trainer_forwards_logger_callbacks_and_config PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_factory.py::test_build_training_trainer_builds_loggers_callbacks_and_trainer PASSED [ 50%]
# ...

# %% [markdown]
# ### 11.4. test_train.py

# %% [markdown]
# This test validates training execution utilities.
#
# It checks that:
# - resume checkpoint paths are resolved correctly;
# - ambiguous restoration configs are rejected;
# - training orchestration calls `trainer.fit`;
# - successful runs are marked as finished;
# - failed runs are marked as failed and re-raised;
# - cleanup and report saving run even after failures.
#
# `monkeypatch` isolates `train.py` orchestration from Setup, factories, Lightning, snapshots, reports, and external services.

# %%
EXECUTION_TEST_TRAIN_FILE = (
    PROJECT_ROOT
    / EXECUTION_TEST_FOLDER
    / "test_train.py"
)

test_train_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(EXECUTION_TEST_TRAIN_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_train_result.stdout)
print(test_train_result.stderr)

assert test_train_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_train.py::test_get_resume_checkpoint_path_returns_none_without_config PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_train.py::test_get_resume_checkpoint_path_returns_none_when_disabled PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_train.py::test_get_resume_checkpoint_path_rejects_missing_checkpoint_when_enabled PASSED [ 37%]
# ...

# %% [markdown]
# ### 11.5. test_evaluate.py

# %% [markdown]
# This test validates evaluation execution utilities.
#
# It checks that:
# - evaluation steps are validated;
# - evaluation resume configs are rejected;
# - Lightning validation/test dispatch works;
# - successful evaluations store outputs and finish correctly;
# - failed evaluations are marked as failed and re-raised;
# - cleanup and report saving run even after failures.
#
# `monkeypatch` isolates `evaluate.py` orchestration from Setup, factories, Lightning, snapshots, reports, and external services.

# %%
EXECUTION_TEST_EVALUATE_FILE = (
    PROJECT_ROOT
    / EXECUTION_TEST_FOLDER
    / "test_evaluate.py"
)

test_evaluate_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(EXECUTION_TEST_EVALUATE_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_evaluate_result.stdout)
print(test_evaluate_result.stderr)

assert test_evaluate_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 9 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_evaluate.py::test_check_evaluation_step_accepts_validate_and_test PASSED [ 11%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_evaluate.py::test_check_evaluation_step_rejects_invalid_step PASSED [ 22%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Execution/test_evaluate.py::test_check_evaluation_restoration_config_accepts_resume_disabled PASSED [ 33%]
# ...

# %% [markdown]
# ### 12. Utils

# %%
UTILS_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Utils"
    
)

# %% [markdown]
# ### 12.1. test_error.py

# %% [markdown]
# This test validates generic error-handling utilities.
#
# It checks that:
# - strict mode raises a `RuntimeError`;
# - non-strict mode emits a warning.

# %%
UTILS_TEST_ERROR_FILE = (
    PROJECT_ROOT
    / UTILS_TEST_FOLDER
    / "test_error.py"
)

test_error_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(UTILS_TEST_ERROR_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_error_result.stdout)
print(test_error_result.stderr)

assert test_error_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 2 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Utils/test_error.py::test_handle_error_raises_runtime_error_in_strict_mode PASSED [ 50%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Utils/test_error.py::test_handle_error_warns_in_non_strict_mode PASSED [100%]
#
# ============================== 2 passed in 0.08s ==============================

# %% [markdown]
# ## 13. Loggers

# %%
LOGGERS_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Loggers"
    
)

# %% [markdown]
# ### 13.1. test_factory.py

# %% [markdown]
# This test validates logger factory utilities.
#
# It checks that:
# - logger paths are resolved correctly;
# - absolute paths are preserved;
# - relative paths can be resolved from the runtime context;
# - unknown runtime path roots are rejected;
# - logger path groups are resolved consistently;
# - empty logger configs disable Lightning logging;
# - named loggers are built correctly;
# - unknown logger names are rejected.

# %%
LOGGERS_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / LOGGERS_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(LOGGERS_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Loggers/test_factory.py::test_resolve_logger_path_keeps_absolute_path PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Loggers/test_factory.py::test_resolve_logger_path_keeps_relative_path_without_runtime_context PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Loggers/test_factory.py::test_resolve_logger_path_resolves_relative_path_from_runtime_context PASSED [ 37%]
# ...

# %% [markdown]
# ## 14. Checkpoints

# %%
CHECKPOINTS_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Checkpoints"
    
)

# %% [markdown]
# ### 14.1. test_factory.py

# %% [markdown]
# This test validates checkpoint callback factory utilities.
#
# It checks that:
# - default checkpoint directories are resolved correctly;
# - runtime path roots are validated;
# - checkpoint dirpaths are resolved consistently;
# - default checkpoint callbacks are built correctly;
# - unknown checkpoint types are rejected;
# - missing checkpoint types are rejected.

# %%
CHECKPOINTS_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / CHECKPOINTS_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(CHECKPOINTS_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 10 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Checkpoints/test_factory.py::test_get_default_checkpoint_dir_returns_none_without_runtime_context PASSED [ 10%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Checkpoints/test_factory.py::test_get_default_checkpoint_dir_returns_context_checkpoint_dir PASSED [ 20%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Checkpoints/test_factory.py::test_get_default_checkpoint_dir_rejects_missing_checkpoint_dir PASSED [ 30%]
# ...

# %% [markdown]
# ## 15. Early Stoppings

# %%
EARLY_STOPPINGS_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "EarlyStoppings"
    
)

# %% [markdown]
# ### 15.1. test_factory.py

# %% [markdown]
# This test validates early stopping callback factory utilities.
#
# It checks that:
# - stagnation early stopping callbacks are built correctly;
# - threshold early stopping callbacks enforce zero patience;
# - divergence early stopping callbacks enforce zero patience;
# - finite-value early stopping callbacks enforce finite checking;
# - default early stopping callback groups are built correctly;
# - unknown early stopping types are rejected;
# - missing early stopping types are rejected.

# %%
EARLY_STOPPINGS_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / EARLY_STOPPINGS_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(EARLY_STOPPINGS_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 7 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/EarlyStoppings/test_factory.py::test_best_value_stagnation_builder_builds_early_stopping PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/EarlyStoppings/test_factory.py::test_threshold_builder_builds_zero_patience_early_stopping PASSED [ 28%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/EarlyStoppings/test_factory.py::test_divergence_builder_builds_zero_patience_early_stopping PASSED [ 42%]
# ...

# %% [markdown]
# ## 16. Sweeps

# %%
SWEEPS_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Sweeps"
    
)

# %% [markdown]
# ### 16.1. test_factory.py

# %% [markdown]
# This test validates WandB sweep factory utilities.
#
# It checks that:
# - dotted-path config values are injected correctly;
# - invalid dotted paths are rejected;
# - multiple sampled parameters can be injected;
# - trial config creation does not mutate the base config;
# - WandB run names are propagated to the trial config.

# %%
SWEEPS_TEST_FACTORY_FILE = (
    PROJECT_ROOT
    / SWEEPS_TEST_FOLDER
    / "test_factory.py"
)

test_factory_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SWEEPS_TEST_FACTORY_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_factory_result.stdout)
print(test_factory_result.stderr)

assert test_factory_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 7 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Sweeps/test_factory.py::test_set_nested_config_value_updates_existing_nested_key PASSED [ 14%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Sweeps/test_factory.py::test_set_nested_config_value_rejects_missing_intermediate_key PASSED [ 28%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Sweeps/test_factory.py::test_set_nested_config_value_rejects_non_dict_intermediate_key PASSED [ 42%]
# ...

# %% [markdown]
# ### 16.2. test_wandb_sweeps.py

# %% [markdown]
# This test validates WandB sweep orchestration utilities.
#
# It checks that:
# - WandB trials build trial configs and call training;
# - new sweeps create a sweep before launching an agent;
# - existing sweeps launch an agent from a sweep ID;
# - `monkeypatch` isolates tests from real WandB calls and training execution.

# %%
SWEEPS_TEST_WANDB_SWEEPS_FILE = (
    PROJECT_ROOT
    / SWEEPS_TEST_FOLDER
    / "test_wandb_sweeps.py"
)

test_wandb_sweeps_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SWEEPS_TEST_WANDB_SWEEPS_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_wandb_sweeps_result.stdout)
print(test_wandb_sweeps_result.stderr)

assert test_wandb_sweeps_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 3 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Sweeps/test_wandb_sweeps.py::test_run_wandb_trial_builds_trial_config_and_runs_training PASSED [ 33%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Sweeps/test_wandb_sweeps.py::test_run_wandb_sweep_creates_sweep_and_launches_agent PASSED [ 66%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Sweeps/test_wandb_sweeps.py::test_run_existing_wandb_sweep_launches_agent PASSED [100%]
#
# ============================= 3 passed in 12.75s ==============================

# %% [markdown]
# ## 17. Scripts

# %%
SCRIPTS_TEST_FOLDER  = (
    PROJECT_ROOT
    / "Project_1_SepFormer_TSE_HF"
    / "idea_1_project_setup"
    / "unit_tests"
    / "Scripts"
    
)

# %% [markdown]
# ### 17.1. test_launch.py

# %% [markdown]
# This test validates `scripts/launch.py` as a thin CLI dispatcher.
#
# - Checks launch mode inference for:
#   - training runs,
#   - validation runs,
#   - sweeps.
# - Verifies that configs are resolved before being loaded.
# - Verifies dispatch to the correct workflow entry point.
# - Uses monkeypatching to avoid real training, evaluation, WandB, or filesystem-heavy behavior.

# %%
SCRIPTS_TEST_LAUNCH_FILE = (
    PROJECT_ROOT
    / SCRIPTS_TEST_FOLDER
    / "test_launch.py"
)

test_launch_result = subprocess.run(
    [sys.executable, "-m", "pytest", str(SCRIPTS_TEST_LAUNCH_FILE), "-v"],
    cwd=PROJECT_ROOT,
    text=True,
    capture_output=True,
)

print(test_launch_result.stdout)
print(test_launch_result.stderr)

assert test_launch_result.returncode == 0
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.9, pytest-9.0.3, pluggy-1.6.0 -- c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp\stage_mva\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\octav\Documents\Cours\ENS\Maths\MVA\Stage\Dev\exp
# configfile: pyproject.toml
# collecting ... collected 8 items
#
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Scripts/test_launch.py::test_infer_launch_mode_detects_train_run PASSED [ 12%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Scripts/test_launch.py::test_infer_launch_mode_detects_validation_run PASSED [ 25%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Scripts/test_launch.py::test_infer_launch_mode_detects_sweep PASSED [ 37%]
# Project_1_SepFormer_TSE_HF/idea_1_project_setup/unit_tests/Scripts/test_launch.py::test_infer_launch_mode_unknown_path_raises PASSED [ 50%]
# ...
