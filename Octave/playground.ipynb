# %%
# !pytest C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\Octave\tests\unit\test_ac_video_jepa_collator.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.10, pytest-9.0.3, pluggy-1.6.0
# rootdir: C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW
# configfile: pyproject.toml
# plugins: anyio-4.13.0
# collected 11 items
#
# tests\unit\test_ac_video_jepa_collator.py ...........                    [100%]
#
# ============================== warnings summary ===============================
# ..\.venv312\Lib\site-packages\_pytest\cacheprovider.py:475
#   C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\.venv312\Lib\site-packages\_pytest\cacheprovider.py:475: PytestCacheWarning: could not create cache path C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\.pytest_cache\v\cache\nodeids: [WinError 5] Accès refusé: 'C:\\Users\\octav\\Documents\\Cours\\Hackathons\\JEPA\\HtW\\.pytest_cache\\v\\cache'
#     config.cache.set("cache/nodeids", sorted(self.cached_nodeids))
#
# ...

# %%
# !pytest C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\Octave\tests\unit\test_ac_video_jepa_datamodule.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.10, pytest-9.0.3, pluggy-1.6.0
# rootdir: C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW
# configfile: pyproject.toml
# plugins: anyio-4.13.0
# collected 0 items / 1 error
#
# =================================== ERRORS ====================================
# _____ ERROR collecting Octave/tests/unit/test_ac_video_jepa_datamodule.py _____
# ImportError while importing test module 'C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\Octave\tests\unit\test_ac_video_jepa_datamodule.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# C:\Users\octav\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tests\unit\test_ac_video_jepa_datamodule.py:8: in <module>
# ...

# %%
# !pytest C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\Octave\tests\unit\test_two_rooms_dataset_factory.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.10, pytest-9.0.3, pluggy-1.6.0
# rootdir: C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW
# configfile: pyproject.toml
# plugins: anyio-4.13.0
# collected 7 items
#
# tests\unit\test_two_rooms_dataset_factory.py .......                     [100%]
#
# ============================== warnings summary ===============================
# ..\.venv312\Lib\site-packages\_pytest\cacheprovider.py:475
#   C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\.venv312\Lib\site-packages\_pytest\cacheprovider.py:475: PytestCacheWarning: could not create cache path C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\.pytest_cache\v\cache\nodeids: [WinError 5] Accès refusé: 'C:\\Users\\octav\\Documents\\Cours\\Hackathons\\JEPA\\HtW\\.pytest_cache\\v\\cache'
#     config.cache.set("cache/nodeids", sorted(self.cached_nodeids))
#
# ...
