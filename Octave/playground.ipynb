# %%
# !pytest C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\Octave\tests\unit\test_checkpoints.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.12.10, pytest-9.0.3, pluggy-1.6.0
# rootdir: C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW
# configfile: pyproject.toml
# plugins: anyio-4.13.0
# collected 1 item
#
# tests\unit\test_checkpoints.py .                                         [100%]
#
# ============================== warnings summary ===============================
# ..\.venv312\Lib\site-packages\_pytest\cacheprovider.py:475
#   C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\.venv312\Lib\site-packages\_pytest\cacheprovider.py:475: PytestCacheWarning: could not create cache path C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\.pytest_cache\v\cache\nodeids: [WinError 5] Accès refusé: 'C:\\Users\\octav\\Documents\\Cours\\Hackathons\\JEPA\\HtW\\.pytest_cache\\v\\cache'
#     config.cache.set("cache/nodeids", sorted(self.cached_nodeids))
#
# ...

# %%
# !python launch.py /teamspace/studios/this_studio/HtW/Octave/configs/runs/ac_video_jepa_train.yaml

# %%
# !python launch.py C:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\Octave\configs\runs\ac_video_jepa_train.yaml --mode train
# Out:
# ┌───┬───────┬─────────────┬────────┬───────┬───────┐
# │   │ Name  │ Type        │ Params │ Mode  │ FLOPs │
# ├───┼───────┼─────────────┼────────┼───────┼───────┤
# │ 0 │ model │ AcVideoJepa │  2.3 M │ train │     0 │
# └───┴───────┴─────────────┴────────┴───────┴───────┘
# Trainable params: 2.3 M
# Non-trainable params: 0
# Total params: 2.3 M
# Total estimated model params size (MB): 9.075
# Modules in train mode: 54
# Modules in eval mode: 0
# Total FLOPs: 0
#
# c:\Users\octav\Documents\Cours\Hackathons\JEPA\HtW\.venv312\Lib\site-packages\t
# orch\utils\data\dataloader.py:624: UserWarning: This DataLoader will create 16
# worker processes in total. Our suggested max number of worker in current system
# is 8 (`cpuset` is not taken into account), which is smaller than what this
# DataLoader is going to create. Please be aware that excessive worker creation
# might get DataLoader running slow or even freeze, lower the worker number to
# avoid potential slowness/freeze if necessary.
# ...
